# %% [markdown]
# # Superbowl History

# %% [markdown]
# Imported data libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# After this, I imported my Superbowl dataset via Kaggle.com and done some routine cleaning and checks to see what I am working with

# %%
df = pd.read_csv(r"C:\Users\Issa.Flynn\Desktop\superbowl.csv")
df.dropna(axis=1)
df.fillna('NaN')
df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        54 non-null     object
#  1   Year        54 non-null     int64
#  2   SB          54 non-null     object
#  3   Winner      54 non-null     object
#  4   Winner Pts  54 non-null     int64
#  5   Loser       54 non-null     object
#  6   Loser Pts   54 non-null     int64
#  7   MVP         54 non-null     object
#  8   Stadium     54 non-null     object
#  9   City        54 non-null     object
#  10  State       54 non-null     object
# dtypes: int64(3), object(8)
# memory usage: 4.8+ KB

# %% [markdown]
# Printed out the first 5 rows just to see if everything was looking ok!

# %%
df.head()
# Out:
#      Date  Year         SB                Winner  Winner Pts  \
# 0  Feb-02  2020   LIV (54)    Kansas City Chiefs          31
# 1  Feb-03  2019  LIII (53)  New England Patriots          13
# 2  Feb-04  2018   LII (52)   Philadelphia Eagles          41
# 3  Feb-05  2017    LI (51)  New England Patriots          34
# 4  Feb-07  2016         50        Denver Broncos          24
#
#                   Loser  Loser Pts              MVP                Stadium  \
# 0   San Francisco 49ers         20  Patrick Mahomes      Hard Rock Stadium
# 1      Los Angeles Rams          3   Julian Edelman  Mercedes-Benz Stadium
# 2  New England Patriots         33       Nick Foles      U.S. Bank Stadium
# 3       Atlanta Falcons         28        Tom Brady            NRG Stadium
# 4     Carolina Panthers         10       Von Miller         Levi's Stadium
#
#             City       State
# 0  Miami Gardens     Florida
# 1        Atlanta     Georgia
# 2    Minneapolis   Minnesota
# 3        Houston       Texas
# 4    Santa Clara  California

# %% [markdown]
# I coverted my dataset into a dataframe and printed this out

# %%
pd.DataFrame(df)
df
# Out:
#       Date  Year            SB                Winner  Winner Pts  \
# 0   Feb-02  2020      LIV (54)    Kansas City Chiefs          31
# 1   Feb-03  2019     LIII (53)  New England Patriots          13
# 2   Feb-04  2018      LII (52)   Philadelphia Eagles          41
# 3   Feb-05  2017       LI (51)  New England Patriots          34
# 4   Feb-07  2016            50        Denver Broncos          24
# 5   Feb-01  2015     XLIX (49)  New England Patriots          28
# 6   Feb-02  2014   XLVIII (48)      Seattle Seahawks          43
# 7   Feb-03  2013    XLVII (47)      Baltimore Ravens          34
# 8   Feb-05  2012     XLVI (46)       New York Giants          21
# 9   Feb-06  2011      XLV (45)     Green Bay Packers          31
# 10  Feb-07  2010     XLIV (44)    New Orleans Saints          31
# 11  Feb-01  2009    XLIII (43)   Pittsburgh Steelers          27
# 12  Feb-03  2008     XLII (42)       New York Giants          17
# 13  Feb-04  2007      XLI (41)    Indianapolis Colts          29
# 14  Feb-05  2006       XL (40)   Pittsburgh Steelers          21
# 15  Feb-06  2005    XXXIX (39)  New England Patriots          24
# 16  Feb-01  2004  XXXVIII (38)  New England Patriots          32
# 22               Qualcomm Stadium        San Diego  California
# 23            Louisiana Superdome      New Orleans   Louisiana
# 24              Sun Devil Stadium            Tempe     Arizona
# 25             Joe Robbie Stadium    Miami Gardens     Florida
# 26                   Georgia Dome          Atlanta     Georgia
# 27                      Rose Bowl         Pasadena  California
# 28                      Metrodome      Minneapolis   Minnesota
# 29                  Tampa Stadium            Tampa     Florida
# 30            Louisiana Superdome      New Orleans   Louisiana
# 31             Joe Robbie Stadium    Miami Gardens     Florida
# 32            Jack Murphy Stadium        San Diego  California
# 33                      Rose Bowl         Pasadena  California
# 34            Louisiana Superdome      New Orleans   Louisiana
# 35               Stanford Stadium        Palo Alto  California
# 36                  Tampa Stadium            Tampa     Florida
# 37                      Rose Bowl         Pasadena  California
# 38             Pontiac Silverdome          Pontiac    Michigan
# 39            Louisiana Superdome      New Orleans   Louisiana
# 40                      Rose Bowl         Pasadena  California
# 41                    Orange Bowl            Miami     Florida
# 42                      Superdome      New Orleans   Louisiana
# 43                      Rose Bowl         Pasadena  California
# 44                    Orange Bowl            Miami     Florida
# 45                 Tulane Stadium      New Orleans   Louisiana
# 46                   Rice Stadium          Houston       Texas
# 47              Memorial Coliseum      Los Angeles  California
# 48                 Tulane Stadium      New Orleans   Louisiana
# 49                    Orange Bowl            Miami     Florida
# 50                 Tulane Stadium      New Orleans   Louisiana
# 51                    Orange Bowl            Miami     Florida
# 52                    Orange Bowl            Miami     Florida
# 53              Memorial Coliseum      Los Angeles  California

# %% [markdown]
# I then imported a second dataset with information regarding the game for the last 3 seasons

# %%
df2 = pd.read_csv(r"C:\Users\Issa.Flynn\OneDrive - Bytedance\superbowl_new.csv")
df2 = pd.DataFrame(df2)
df2
# Out:
#      Date  Year        SB                Winner  Winner Pts  \
# 0  Feb-01  2021    LV(55)  Tampa Bay Buccaneers          31
# 1  Feb-13  2022   LVI(56)      Los Angeles Rams          23
# 2  Feb-12  2023  LVII(57)    Kansas City Chiefs          38
#
#                  Loser  Loser Pts              MVP                Stadium  \
# 0   Kansas City Chiefs          9        Tom Brady  Raymond James Stadium
# 1   Cincinnati Bengals         20      Cooper Kupp           SoFi Stadium
# 2  Philadelphia Eagles         35  Patrick Mahomes     State Farm Stadium
#
#         City       State
# 0      Tampa     Florida
# 1  Inglewood  California
# 2   Glendale     Arizona

# %% [markdown]
# I merged the 2 datasets together

# %%
combined = ([df, df2])
superbowl = pd.concat(combined)
superbowl
# Out:
#       Date  Year            SB                Winner  Winner Pts  \
# 0   Feb-02  2020      LIV (54)    Kansas City Chiefs          31
# 1   Feb-03  2019     LIII (53)  New England Patriots          13
# 2   Feb-04  2018      LII (52)   Philadelphia Eagles          41
# 3   Feb-05  2017       LI (51)  New England Patriots          34
# 4   Feb-07  2016            50        Denver Broncos          24
# 5   Feb-01  2015     XLIX (49)  New England Patriots          28
# 6   Feb-02  2014   XLVIII (48)      Seattle Seahawks          43
# 7   Feb-03  2013    XLVII (47)      Baltimore Ravens          34
# 8   Feb-05  2012     XLVI (46)       New York Giants          21
# 2              State Farm Stadium         Glendale     Arizona
# 1                    SoFi Stadium        Inglewood  California
# 0           Raymond James Stadium            Tampa     Florida
# 0               Hard Rock Stadium    Miami Gardens     Florida
# 1           Mercedes-Benz Stadium          Atlanta     Georgia
# 2               U.S. Bank Stadium      Minneapolis   Minnesota
# 3                     NRG Stadium          Houston       Texas
# 4                  Levi's Stadium      Santa Clara  California
# 5   University of Phoenix Stadium         Glendale     Arizona
# 6                 MetLife Stadium  East Rutherford  New Jersey
# 7         Mercedes-Benz Superdome      New Orleans   Louisiana
# 8               Lucas Oil Stadium     Indianapolis     Indiana
# 9                 Cowboys Stadium        Arlington       Texas
# 10               Sun Life Stadium    Miami Gardens     Florida
# 11          Raymond James Stadium            Tampa     Florida
# 12  University of Phoenix Stadium         Glendale     Arizona
# 13                Dolphin Stadium    Miami Gardens     Florida
# 14                     Ford Field          Detroit    Michigan
# 15                 Alltel Stadium     Jacksonville     Florida
# 16                Reliant Stadium          Houston       Texas
# 17               Qualcomm Stadium        San Diego  California
# 18            Louisiana Superdome      New Orleans   Louisiana
# 19          Raymond James Stadium            Tampa     Florida
# 20                   Georgia Dome          Atlanta     Georgia
# 21             Pro Player Stadium    Miami Gardens     Florida
# 22               Qualcomm Stadium        San Diego  California
# 23            Louisiana Superdome      New Orleans   Louisiana
# 24              Sun Devil Stadium            Tempe     Arizona
# 25             Joe Robbie Stadium    Miami Gardens     Florida
# 26                   Georgia Dome          Atlanta     Georgia
# 27                      Rose Bowl         Pasadena  California
# 28                      Metrodome      Minneapolis   Minnesota
# 29                  Tampa Stadium            Tampa     Florida
# 30            Louisiana Superdome      New Orleans   Louisiana
# 31             Joe Robbie Stadium    Miami Gardens     Florida
# 32            Jack Murphy Stadium        San Diego  California
# 33                      Rose Bowl         Pasadena  California
# 34            Louisiana Superdome      New Orleans   Louisiana
# 35               Stanford Stadium        Palo Alto  California
# 36                  Tampa Stadium            Tampa     Florida
# 37                      Rose Bowl         Pasadena  California
# 38             Pontiac Silverdome          Pontiac    Michigan
# 39            Louisiana Superdome      New Orleans   Louisiana
# 40                      Rose Bowl         Pasadena  California
# 41                    Orange Bowl            Miami     Florida
# 42                      Superdome      New Orleans   Louisiana
# 43                      Rose Bowl         Pasadena  California
# 44                    Orange Bowl            Miami     Florida
# 45                 Tulane Stadium      New Orleans   Louisiana
# 46                   Rice Stadium          Houston       Texas
# 47              Memorial Coliseum      Los Angeles  California
# 48                 Tulane Stadium      New Orleans   Louisiana
# 49                    Orange Bowl            Miami     Florida
# 50                 Tulane Stadium      New Orleans   Louisiana
# 51                    Orange Bowl            Miami     Florida
# 52                    Orange Bowl            Miami     Florida
# 53              Memorial Coliseum      Los Angeles  California

# %% [markdown]
# I will call the describe function to tell us more about the integers in our dataframe

# %%
superbowl.describe().round(decimals=1).drop(['Year'], axis=1)
# Out:
#        Winner Pts  Loser Pts
# count        57.0       57.0
# mean         30.1       16.5
# std           9.6        7.7
# min          13.0        3.0
# 25%          23.0       10.0
# 50%          31.0       17.0
# 75%          35.0       21.0
# max          55.0       35.0

# %% [markdown]
# Now that I have my data in order, I am going to see who has won/lost the superbowl on the most occasions and represent this on 2 seperate bar charts.

# %%
# Winners bar plot
superbowl_new['Count'] = 1
superbowl_grp_win = superbowl_new.groupby('Winner').sum()['Count'].reset_index().sort_values(by = 'Count', ascending=False)
superbowl_grp_win.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_869cf_" ><thead>    <tr>        <th class="col_heading level0 col0" >Winner</th>        <th class="col_heading level0 col1" >Count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_869cf_row0_col0" class="data row0 col0" >New England Patriots</td>
#                         <td id="T_869cf_row0_col1" class="data row0 col1" >6</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row1_col0" class="data row1 col0" >Pittsburgh Steelers</td>
#                         <td id="T_869cf_row1_col1" class="data row1 col1" >6</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row2_col0" class="data row2 col0" >San Francisco 49ers</td>
#                         <td id="T_869cf_row2_col1" class="data row2 col1" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row3_col0" class="data row3 col0" >Dallas Cowboys</td>
#                         <td id="T_869cf_row3_col1" class="data row3 col1" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row4_col0" class="data row4 col0" >Green Bay Packers</td>
#                         <td id="T_869cf_row4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row5_col0" class="data row5 col0" >New York Giants</td>
#                         <td id="T_869cf_row5_col1" class="data row5 col1" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row6_col0" class="data row6 col0" >Kansas City Chiefs</td>
#                         <td id="T_869cf_row6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row7_col0" class="data row7 col0" >Washington Redskins</td>
#                         <td id="T_869cf_row7_col1" class="data row7 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row8_col0" class="data row8 col0" >Denver Broncos</td>
#                         <td id="T_869cf_row8_col1" class="data row8 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row9_col0" class="data row9 col0" >Miami Dolphins</td>
#                         <td id="T_869cf_row9_col1" class="data row9 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row10_col0" class="data row10 col0" >Baltimore Ravens</td>
#                         <td id="T_869cf_row10_col1" class="data row10 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row11_col0" class="data row11 col0" >Oakland Raiders</td>
#                         <td id="T_869cf_row11_col1" class="data row11 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row12_col0" class="data row12 col0" >Tampa Bay Buccaneers</td>
#                         <td id="T_869cf_row12_col1" class="data row12 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row13_col0" class="data row13 col0" >Los Angeles Raiders</td>
#                         <td id="T_869cf_row13_col1" class="data row13 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row14_col0" class="data row14 col0" >Los Angeles Rams</td>
#                         <td id="T_869cf_row14_col1" class="data row14 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row15_col0" class="data row15 col0" >New Orleans Saints</td>
#                         <td id="T_869cf_row15_col1" class="data row15 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row16_col0" class="data row16 col0" >Indianapolis Colts</td>
#                         <td id="T_869cf_row16_col1" class="data row16 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row17_col0" class="data row17 col0" >New York Jets</td>
#                         <td id="T_869cf_row17_col1" class="data row17 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row18_col0" class="data row18 col0" >Philadelphia Eagles</td>
#                         <td id="T_869cf_row18_col1" class="data row18 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row19_col0" class="data row19 col0" >Chicago Bears</td>
#                         <td id="T_869cf_row19_col1" class="data row19 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row20_col0" class="data row20 col0" >Seattle Seahawks</td>
#                         <td id="T_869cf_row20_col1" class="data row20 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row21_col0" class="data row21 col0" >St. Louis Rams</td>
#                         <td id="T_869cf_row21_col1" class="data row21 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_869cf_row22_col0" class="data row22 col0" >Baltimore Colts</td>
#                         <td id="T_869cf_row22_col1" class="data row22 col1" >1</td>
#             </tr>
#     </tbody></table>

# %%
plt.figure(figsize=(88,48))
w = sns.barplot(x='Winner', y='Count', data=superbowl_grp_win)
w.set_title('Superbowl Appearances As A Winning Team', y=1)
w.set(xlabel='Team', ylabel='Count')
plt.show()

# %%
# Losers bar plot
superbowl_new['Count'] = 1
superbowl_grp_los = superbowl_new.groupby('Loser').sum()['Count'].reset_index().sort_values(by = 'Count', ascending=False)
superbowl_grp_los.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_16e7d_" ><thead>    <tr>        <th class="col_heading level0 col0" >Loser</th>        <th class="col_heading level0 col1" >Count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_16e7d_row0_col0" class="data row0 col0" >Denver Broncos</td>
#                         <td id="T_16e7d_row0_col1" class="data row0 col1" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row1_col0" class="data row1 col0" >New England Patriots</td>
#                         <td id="T_16e7d_row1_col1" class="data row1 col1" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row2_col0" class="data row2 col0" >Buffalo Bills</td>
#                         <td id="T_16e7d_row2_col1" class="data row2 col1" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row3_col0" class="data row3 col0" >Minnesota Vikings</td>
#                         <td id="T_16e7d_row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row4_col0" class="data row4 col0" >Miami Dolphins</td>
#                         <td id="T_16e7d_row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row5_col0" class="data row5 col0" >Cincinnati Bengals</td>
#                         <td id="T_16e7d_row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row6_col0" class="data row6 col0" >Dallas Cowboys</td>
#                         <td id="T_16e7d_row6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row7_col0" class="data row7 col0" >Philadelphia Eagles</td>
#                         <td id="T_16e7d_row7_col1" class="data row7 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row8_col0" class="data row8 col0" >Atlanta Falcons</td>
#                         <td id="T_16e7d_row8_col1" class="data row8 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row9_col0" class="data row9 col0" >Seattle Seahawks</td>
#                         <td id="T_16e7d_row9_col1" class="data row9 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row10_col0" class="data row10 col0" >San Francisco 49ers</td>
#                         <td id="T_16e7d_row10_col1" class="data row10 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row11_col0" class="data row11 col0" >Pittsburgh Steelers</td>
#                         <td id="T_16e7d_row11_col1" class="data row11 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row12_col0" class="data row12 col0" >Oakland Raiders</td>
#                         <td id="T_16e7d_row12_col1" class="data row12 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row13_col0" class="data row13 col0" >Washington Redskins</td>
#                         <td id="T_16e7d_row13_col1" class="data row13 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row14_col0" class="data row14 col0" >Los Angeles Rams</td>
#                         <td id="T_16e7d_row14_col1" class="data row14 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row15_col0" class="data row15 col0" >Kansas City Chiefs</td>
#                         <td id="T_16e7d_row15_col1" class="data row15 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row16_col0" class="data row16 col0" >Carolina Panthers</td>
#                         <td id="T_16e7d_row16_col1" class="data row16 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row17_col0" class="data row17 col0" >New York Giants</td>
#                         <td id="T_16e7d_row17_col1" class="data row17 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row18_col0" class="data row18 col0" >Indianapolis Colts</td>
#                         <td id="T_16e7d_row18_col1" class="data row18 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row19_col0" class="data row19 col0" >Green Bay Packers</td>
#                         <td id="T_16e7d_row19_col1" class="data row19 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row20_col0" class="data row20 col0" >Chicago Bears</td>
#                         <td id="T_16e7d_row20_col1" class="data row20 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row21_col0" class="data row21 col0" >San Diego Chargers</td>
#                         <td id="T_16e7d_row21_col1" class="data row21 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row22_col0" class="data row22 col0" >Baltimore Colts</td>
#                         <td id="T_16e7d_row22_col1" class="data row22 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row23_col0" class="data row23 col0" >St. Louis Rams</td>
#                         <td id="T_16e7d_row23_col1" class="data row23 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row24_col0" class="data row24 col0" >Tennessee Titans</td>
#                         <td id="T_16e7d_row24_col1" class="data row24 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_16e7d_row25_col0" class="data row25 col0" >Arizona Cardinals</td>
#                         <td id="T_16e7d_row25_col1" class="data row25 col1" >1</td>
#             </tr>
#     </tbody></table>

# %%
plt.figure(figsize=(88,66))
L = sns.barplot(x='Loser', y='Count', data=superbowl_grp_los)
L.set_title('Superbowl Appearances As A Losing Team', y=1)
L.set(xlabel='Team', ylabel='Count')
plt.show()

# %% [markdown]
# I am now going to dive into the scoring history of the competition and see the highest and lowest scores by the winning and losing team.

# %% [markdown]
# Highest scoring winning team in the Superbowl

# %%
superbowl_new_winhigh = superbowl_new[superbowl_new['Winner Pts'] == superbowl_new['Winner Pts'].max()][['Year', 'Winner', 'Winner Pts']]
superbowl_new_winhigh
# Out:
#         Year               Winner  Winner Pts
# Date
# Jan-28  1990  San Francisco 49ers          55

# %% [markdown]
# San Francisco 49ers have scored the most winning points in the Superbowl. Lets find out the opposite!

# %%
superbowl_new_winlow = superbowl_new[superbowl_new['Winner Pts'] == superbowl_new['Winner Pts'].min()][['Year', 'Winner', 'Winner Pts']]
superbowl_new_winlow
# Out:
#         Year                Winner  Winner Pts
# Date
# Feb-03  2019  New England Patriots          13

# %% [markdown]
# The New England Patriots scored the least points as a winning team back in 2019. Moving along, going back to our earlier call of  the describe method of the merged dataframe, we can see that the mean score by a winning team is 30 points, lets see how many winning teams achieved such score or higher.

# %%
arr_win = np.mean(superbowl_new['Winner Pts'])
superbowl_new['mean_winnerpts'] = np.round(arr_win).astype(int)

# %%
winners_avg = superbowl_new[superbowl_new['Winner Pts'] > mean_winnerpts]
winners_avg[['Winner', 'Winner Pts']]
# Out:
#                   Winner  Winner Pts
# 2     Kansas City Chiefs          38
# 0   Tampa Bay Buccaneers          31
# 0     Kansas City Chiefs          31
# 2    Philadelphia Eagles          41
# 3   New England Patriots          34
# 6       Seattle Seahawks          43
# 7       Baltimore Ravens          34
# 9      Green Bay Packers          31
# 10    New Orleans Saints          31
# 16  New England Patriots          32
# 17  Tampa Bay Buccaneers          48
# 19      Baltimore Ravens          34
# 21        Denver Broncos          34
# 22        Denver Broncos          31
# 23     Green Bay Packers          35
# 25   San Francisco 49ers          49
# 27        Dallas Cowboys          52
# 28   Washington Redskins          37
# 30   San Francisco 49ers          55
# 32   Washington Redskins          42
# 33       New York Giants          39
# 34         Chicago Bears          46
# 35   San Francisco 49ers          38
# 36   Los Angeles Raiders          38
# 40   Pittsburgh Steelers          31
# 41   Pittsburgh Steelers          35
# 43       Oakland Raiders          32
# 52     Green Bay Packers          33
# 53     Green Bay Packers          35

# %% [markdown]
#  Lets graph the points scored by winning teams vs the average

# %%
plt.subplots(figsize=(20,10))
plt.plot(superbowl_new['Year'],superbowl_new['Winner Pts'], marker='o', label='Winner', color='purple')
plt.plot(superbowl_new['Year'],superbowl_new['mean_winnerpts'], marker='.', label='Mean', color='red')

plt.xlabel('Date (Years)')
plt.ylabel('Points Scored')
plt.title('Losing points scored vs Losing Average', y=1)
plt.legend()
plt.show()

# %% [markdown]
# Here is some code to find out the total % of winning teams who have scored over the average

# %%
winner_overavg = winners_avg['Winner'].count() / 57 * 100
winner_overavg = np.round(winner_overavg).astype(int)
winner_overavg
# Out:
# 51

# %% [markdown]
# Now I want to see how many winning teams have scored less than the mean points in the Superbowl

# %%
winner_notavg = superbowl_new[superbowl_new['Winner Pts'] < mean_winnerpts]
winner_notavg[['Winner', 'Winner Pts']]
# Out:
#                     Winner  Winner Pts
# Year
# 2022      Los Angeles Rams          23
# 2019  New England Patriots          13
# 2016        Denver Broncos          24
# 2015  New England Patriots          28
# 2012       New York Giants          21
# 2009   Pittsburgh Steelers          27
# 2008       New York Giants          17
# 2007    Indianapolis Colts          29
# 2006   Pittsburgh Steelers          21
# 2005  New England Patriots          24
# 2002  New England Patriots          20
# 2000        St. Louis Rams          23
# 1996        Dallas Cowboys          27
# 1991       New York Giants          20
# 1989   San Francisco 49ers          20
# 1983   Washington Redskins          27
# 1982   San Francisco 49ers          26
# 1981       Oakland Raiders          27
# 1978        Dallas Cowboys          27
# 1976   Pittsburgh Steelers          21
# 1975   Pittsburgh Steelers          16
# 1974        Miami Dolphins          24
# 1973        Miami Dolphins          14
# 1972        Dallas Cowboys          24
# 1971       Baltimore Colts          16
# 1970    Kansas City Chiefs          23
# 1969         New York Jets          16

# %% [markdown]
# Now to find out the total % of teams who have scored under the average by dividing by 57(total number of winning teams) and multiply by 100

# %%
winners_underavg = winner_notavg['Winner'].count() / 57 * 100
winners_underavg = np.round(winner_underavg).astype(int)
winners_underavg
# Out:
# 47

# %% [markdown]
# It is only right if we check to see if any winners scored exactly 30 points

# %%
winners_equal = superbowl_new[superbowl_new['Winner Pts'] == mean_winnerpts]
winners_equal[['Winner', 'Winner Pts']]
# Out:
#               Winner  Winner Pts
# Year
# 1994  Dallas Cowboys          30

# %% [markdown]
# We want to check the % of winning finalists that have scored exactly the average

# %%
winners_equalavg = winners_equal['Winner'].count() / 57 * 100
winners_equalavg = np.round(winners_equalavg).astype(int)
winners_equalavg
# Out:
# 2

# %% [markdown]
#  We will do the same but for losing teams and will start off with who scored the highest points tally for a losing finalist

# %%
superbowl_new_losehigh = superbowl_new[superbowl_new['Loser Pts'] == superbowl_new['Loser Pts'].max()][['Year', 'Loser', 'Loser Pts']]
superbowl_new_losehigh
# Out:
#         Year                Loser  Loser Pts
# Date
# Feb-12  2023  Philadelphia Eagles         35

# %% [markdown]
# Philadelphia Eagles in this years Superbowl managed to score the highest points by a losing team now to check the lowest score!

# %%
superbowl_new_loselow = superbowl_new[superbowl_new['Loser Pts'] == superbowl_new['Loser Pts'].min()][['Year', 'Loser', 'Loser Pts']]
superbowl_new_loselow
# Out:
#         Year             Loser  Loser Pts
# Date
# Feb-03  2019  Los Angeles Rams          3
# Jan-16  1972    Miami Dolphins          3

# %% [markdown]
# Los Angeles Rams and Miami Dolphins	both scored the lowest tally by a losing team with just 3 points total

# %% [markdown]
# Going back to our describe call, we can see that the average points scored by a losing team is 16.5(it was rounded up from 16.47) therefore we will round down to 16. Lets find out how many losing finalists have scored over and under this average score.

# %%
arr1 = np.mean(superbowl_new['Loser Pts'])
superbowl_new['mean_loserpts'] = np.round(arr1).astype(int)

# %% [markdown]
# now we will do the same but for the points scored by losing teams vs the average

# %%
plt.subplots(figsize=(20,10))
plt.plot(superbowl_new['Year'],superbowl_new['Loser Pts'], marker='o', label='Loser', color='green')
plt.plot(superbowl_new['Year'],superbowl_new['mean_loserpts'], marker='.', label='Mean', color='blue')

plt.xlabel('Date (Years)')
plt.ylabel('Points Scored')
plt.title('Losing points scored vs Losing Average', y=1)
plt.legend()
plt.show()

# %%
losers_above_avg= superbowl_new[superbowl_new['Loser Pts'] > superbowl_new['mean_loserpts']]
losers_above_avg[['Loser','Loser Pts']]
# Out:
#                      Loser  Loser Pts
# Year
# 2023   Philadelphia Eagles         35
# 2022    Cincinnati Bengals         20
# 2020   San Francisco 49ers         20
# 2018  New England Patriots         33
# 2017       Atlanta Falcons         28
# 2015      Seattle Seahawks         24
# 2013   San Francisco 49ers         31
# 2012  New England Patriots         17
# 2011   Pittsburgh Steelers         25
# 2010    Indianapolis Colts         17
# 2009     Arizona Cardinals         23
# 2007         Chicago Bears         17
# 2005   Philadelphia Eagles         21
# 2004     Carolina Panthers         29
# 2003       Oakland Raiders         21
# 2002        St. Louis Rams         17
# 1999       Atlanta Falcons         19
# 1998     Green Bay Packers         24
# 1997  New England Patriots         21
# 1996   Pittsburgh Steelers         17
# 1995    San Diego Chargers         26
# 1993         Buffalo Bills         17
# 1992         Buffalo Bills         24
# 1991         Buffalo Bills         19
# 1987        Denver Broncos         20
# 1983        Miami Dolphins         17
# 1982    Cincinnati Bengals         21
# 1980      Los Angeles Rams         19
# 1979        Dallas Cowboys         31
# 1976        Dallas Cowboys         17

# %% [markdown]
# Finding out what % of teams scored above the losing average

# %%
losers_above_avg_new = losers_above_avg['Loser'].count() / 57 * 100
losers_above_avg_new = np.round(losers_above_avg_new).astype(int)
losers_above_avg_new
# Out:
# 53

# %%
losers_under_avg= superbowl_new[superbowl_new['Loser Pts'] < mean_loserpts] 
losers_under_avg[['Loser','Loser Pts']]
# Out:
#                      Loser  Loser Pts
# Year
# 2021    Kansas City Chiefs          9
# 2019      Los Angeles Rams          3
# 2016     Carolina Panthers         10
# 2014        Denver Broncos          8
# 2008  New England Patriots         14
# 2006      Seattle Seahawks         10
# 2001       New York Giants          7
# 1994         Buffalo Bills         13
# 1990        Denver Broncos         10
# 1988        Denver Broncos         10
# 1986  New England Patriots         10
# 1984   Washington Redskins          9
# 1981   Philadelphia Eagles         10
# 1978        Denver Broncos         10
# 1977     Minnesota Vikings         14
# 1975     Minnesota Vikings          6
# 1974     Minnesota Vikings          7
# 1973   Washington Redskins          7
# 1972        Miami Dolphins          3
# 1971        Dallas Cowboys         13
# 1970     Minnesota Vikings          7
# 1969       Baltimore Colts          7
# 1968       Oakland Raiders         14
# 1967    Kansas City Chiefs         10

# %% [markdown]
# % of teams that scored below the average

# %%
losers_under_avg_new = losers_under_avg['Loser'].count() / 57 * 100
losers_under_avg_new = np.round(losers_under_avg_new).astype(int)
losers_under_avg_new
# Out:
# 42

# %% [markdown]
# and finally to check to see if any teams matched the average losing points scored

# %%
losers_equal = superbowl_new[superbowl_new['Loser Pts'] == mean_loserpts]
losers_equal[['Loser', 'Loser Pts']]
# Out:
#                    Loser  Loser Pts
# Year
# 2000    Tennessee Titans         16
# 1989  Cincinnati Bengals         16
# 1985      Miami Dolphins         16

# %% [markdown]
# Call to figure out the percentage of losing finalists to equal the losing average score

# %%
losers_equal_new = losers_equal['Loser'].count() / 57 * 100
losers_equal_new = np.round(losers_equal_new).astype(int)
losers_equal_new
# Out:
# 5

# %% [markdown]
# I want to produce a graph to show the winning and losing points against each other

# %%
plt.subplots(figsize=(16,8))
plt.plot(superbowl_new['Year'],superbowl_new['Winner Pts'], marker='+', label='Winner', color='green')
plt.plot(superbowl_new['Year'],superbowl_new['Loser Pts'], marker='.', label='Loser', color='red')

plt.xlabel('Date (Years)')
plt.ylabel('Points Scored')
plt.title('Winning and Losing team total points scored')
plt.legend()
plt.show()

# %% [markdown]
# Now to move on to the next aspect of our data which is the host venue of this competition

# %%
stadium_lists = ["State Farm Stadium", "SoFi Stadium", "Raymond James Stadium", "Hard Rock Stadium",  "Mercedes-Benz Stadium", 
 "U.S. Bank Stadium", "NRG Stadium", "Levi's Stadium", "University of Phoenix Stadium", "MetLife Stadium", 
 "Mercedes-Benz Superdome", "Lucas Oil Stadium", "Cowboys Stadium", "Sun Life Stadium", "Dolphin Stadium",
"Ford Field", "Alltel Stadium", "Reliant Stadium", "Qualcomm Stadium", "Pro Player Stadium", 
 "Sun Devil Stadium", "Joe Robbie Stadium", "Georgia Dome", "Metrodome", "Jack Murphy Stadium", "Stanford Stadium", 
 "Tampa Stadium", "Pontiac Silverdome", "Louisiana Superdome", "Rose Bowl", "Superdome", "Rice Stadium", "Memorial Coliseum", 
 "Tulane Stadium", "Orange Bowl"]

# %% [markdown]
# We want to move on to other parts of the data, lets look all the different venues that have hosted this iconic tournament

# %%
for x in stadium_lists:
         print(str(x) + ' has hosted the Superbowl at least once ')
# Out:
# State Farm Stadium has hosted the Superbowl at least once
# SoFi Stadium has hosted the Superbowl at least once
# Raymond James Stadium has hosted the Superbowl at least once
# Hard Rock Stadium has hosted the Superbowl at least once
# Mercedes-Benz Stadium has hosted the Superbowl at least once
# U.S. Bank Stadium has hosted the Superbowl at least once
# NRG Stadium has hosted the Superbowl at least once
# Levi's Stadium has hosted the Superbowl at least once
# University of Phoenix Stadium has hosted the Superbowl at least once
# MetLife Stadium has hosted the Superbowl at least once
# Mercedes-Benz Superdome has hosted the Superbowl at least once
# Lucas Oil Stadium has hosted the Superbowl at least once
# Cowboys Stadium has hosted the Superbowl at least once
# Sun Life Stadium has hosted the Superbowl at least once
# Dolphin Stadium has hosted the Superbowl at least once
# Ford Field has hosted the Superbowl at least once
# Alltel Stadium has hosted the Superbowl at least once
# Reliant Stadium has hosted the Superbowl at least once
# Qualcomm Stadium has hosted the Superbowl at least once
# Pro Player Stadium has hosted the Superbowl at least once
# Sun Devil Stadium has hosted the Superbowl at least once
# Joe Robbie Stadium has hosted the Superbowl at least once
# Georgia Dome has hosted the Superbowl at least once
# Metrodome has hosted the Superbowl at least once
# Jack Murphy Stadium has hosted the Superbowl at least once
# Stanford Stadium has hosted the Superbowl at least once
# Tampa Stadium has hosted the Superbowl at least once
# Pontiac Silverdome has hosted the Superbowl at least once
# Louisiana Superdome has hosted the Superbowl at least once
# Rose Bowl has hosted the Superbowl at least once
# Superdome has hosted the Superbowl at least once
# Rice Stadium has hosted the Superbowl at least once
# Memorial Coliseum has hosted the Superbowl at least once
# Tulane Stadium has hosted the Superbowl at least once
# Orange Bowl has hosted the Superbowl at least once

# %% [markdown]
# Lets see how many times each stadium has hosted this iconic trophy.

# %%
stadium_count = superbowl_new.groupby('Stadium').sum()['Count'].reset_index().sort_values(by = 'Count', ascending=False)
stadium_count[:10].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_44c70_" ><thead>    <tr>        <th class="col_heading level0 col0" >Stadium</th>        <th class="col_heading level0 col1" >Count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_44c70_row0_col0" class="data row0 col0" >Orange Bowl</td>
#                         <td id="T_44c70_row0_col1" class="data row0 col1" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row1_col0" class="data row1 col0" >Louisiana Superdome</td>
#                         <td id="T_44c70_row1_col1" class="data row1 col1" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row2_col0" class="data row2 col0" >Rose Bowl</td>
#                         <td id="T_44c70_row2_col1" class="data row2 col1" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row3_col0" class="data row3 col0" >Tulane Stadium</td>
#                         <td id="T_44c70_row3_col1" class="data row3 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row4_col0" class="data row4 col0" >Raymond James Stadium</td>
#                         <td id="T_44c70_row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row5_col0" class="data row5 col0" >Tampa Stadium</td>
#                         <td id="T_44c70_row5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row6_col0" class="data row6 col0" >Qualcomm Stadium</td>
#                         <td id="T_44c70_row6_col1" class="data row6 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row7_col0" class="data row7 col0" >Memorial Coliseum</td>
#                         <td id="T_44c70_row7_col1" class="data row7 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row8_col0" class="data row8 col0" >University of Phoenix Stadium</td>
#                         <td id="T_44c70_row8_col1" class="data row8 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_44c70_row9_col0" class="data row9 col0" >Joe Robbie Stadium</td>
#                         <td id="T_44c70_row9_col1" class="data row9 col1" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Applied a conditional statement to see if stadium hosted count was above or below 4

# %%
stadium_count['equal_or_higher_than_4?'] = stadium_count['Count'].apply(lambda x: 'True' if x >= 4 else 'False')
stadium_count.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_9e396_" ><thead>    <tr>        <th class="col_heading level0 col0" >Stadium</th>        <th class="col_heading level0 col1" >Count</th>        <th class="col_heading level0 col2" >equal_or_higher_than_4?</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9e396_row0_col0" class="data row0 col0" >Orange Bowl</td>
#                         <td id="T_9e396_row0_col1" class="data row0 col1" >5</td>
#                         <td id="T_9e396_row0_col2" class="data row0 col2" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row1_col0" class="data row1 col0" >Louisiana Superdome</td>
#                         <td id="T_9e396_row1_col1" class="data row1 col1" >5</td>
#                         <td id="T_9e396_row1_col2" class="data row1 col2" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row2_col0" class="data row2 col0" >Rose Bowl</td>
#                         <td id="T_9e396_row2_col1" class="data row2 col1" >5</td>
#                         <td id="T_9e396_row2_col2" class="data row2 col2" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row3_col0" class="data row3 col0" >Tulane Stadium</td>
#                         <td id="T_9e396_row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_9e396_row3_col2" class="data row3 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row4_col0" class="data row4 col0" >Raymond James Stadium</td>
#                         <td id="T_9e396_row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_9e396_row4_col2" class="data row4 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row5_col0" class="data row5 col0" >Tampa Stadium</td>
#                         <td id="T_9e396_row5_col1" class="data row5 col1" >2</td>
#                         <td id="T_9e396_row5_col2" class="data row5 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row6_col0" class="data row6 col0" >Qualcomm Stadium</td>
#                         <td id="T_9e396_row6_col1" class="data row6 col1" >2</td>
#                         <td id="T_9e396_row6_col2" class="data row6 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row7_col0" class="data row7 col0" >Memorial Coliseum</td>
#                         <td id="T_9e396_row7_col1" class="data row7 col1" >2</td>
#                         <td id="T_9e396_row7_col2" class="data row7 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row8_col0" class="data row8 col0" >University of Phoenix Stadium</td>
#                         <td id="T_9e396_row8_col1" class="data row8 col1" >2</td>
#                         <td id="T_9e396_row8_col2" class="data row8 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row9_col0" class="data row9 col0" >Joe Robbie Stadium</td>
#                         <td id="T_9e396_row9_col1" class="data row9 col1" >2</td>
#                         <td id="T_9e396_row9_col2" class="data row9 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row10_col0" class="data row10 col0" >Georgia Dome</td>
#                         <td id="T_9e396_row10_col1" class="data row10 col1" >2</td>
#                         <td id="T_9e396_row10_col2" class="data row10 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row11_col0" class="data row11 col0" >Levi's Stadium</td>
#                         <td id="T_9e396_row11_col1" class="data row11 col1" >1</td>
#                         <td id="T_9e396_row11_col2" class="data row11 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row12_col0" class="data row12 col0" >Rice Stadium</td>
#                         <td id="T_9e396_row12_col1" class="data row12 col1" >1</td>
#                         <td id="T_9e396_row12_col2" class="data row12 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row13_col0" class="data row13 col0" >U.S. Bank Stadium</td>
#                         <td id="T_9e396_row13_col1" class="data row13 col1" >1</td>
#                         <td id="T_9e396_row13_col2" class="data row13 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row14_col0" class="data row14 col0" >Dolphin Stadium</td>
#                         <td id="T_9e396_row14_col1" class="data row14 col1" >1</td>
#                         <td id="T_9e396_row14_col2" class="data row14 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row15_col0" class="data row15 col0" >Ford Field</td>
#                         <td id="T_9e396_row15_col1" class="data row15 col1" >1</td>
#                         <td id="T_9e396_row15_col2" class="data row15 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row16_col0" class="data row16 col0" >Superdome</td>
#                         <td id="T_9e396_row16_col1" class="data row16 col1" >1</td>
#                         <td id="T_9e396_row16_col2" class="data row16 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row17_col0" class="data row17 col0" >Sun Life Stadium</td>
#                         <td id="T_9e396_row17_col1" class="data row17 col1" >1</td>
#                         <td id="T_9e396_row17_col2" class="data row17 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row18_col0" class="data row18 col0" >Sun Devil Stadium</td>
#                         <td id="T_9e396_row18_col1" class="data row18 col1" >1</td>
#                         <td id="T_9e396_row18_col2" class="data row18 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row19_col0" class="data row19 col0" >State Farm Stadium</td>
#                         <td id="T_9e396_row19_col1" class="data row19 col1" >1</td>
#                         <td id="T_9e396_row19_col2" class="data row19 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row20_col0" class="data row20 col0" >Stanford Stadium</td>
#                         <td id="T_9e396_row20_col1" class="data row20 col1" >1</td>
#                         <td id="T_9e396_row20_col2" class="data row20 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row21_col0" class="data row21 col0" >SoFi Stadium</td>
#                         <td id="T_9e396_row21_col1" class="data row21 col1" >1</td>
#                         <td id="T_9e396_row21_col2" class="data row21 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row22_col0" class="data row22 col0" >Reliant Stadium</td>
#                         <td id="T_9e396_row22_col1" class="data row22 col1" >1</td>
#                         <td id="T_9e396_row22_col2" class="data row22 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row23_col0" class="data row23 col0" >Lucas Oil Stadium</td>
#                         <td id="T_9e396_row23_col1" class="data row23 col1" >1</td>
#                         <td id="T_9e396_row23_col2" class="data row23 col2" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e396_row24_col0" class="data row24 col0" >Hard Rock Stadium</td>
#                         <td id="T_9e396_row24_col1" class="data row24 col1" >1</td>
#                         <td id="T_9e396_row24_col2

# %% [markdown]
# we will move on to cities and states that have hosted this competition over the last 10 year

# %%
superbowl_new.iloc[:10, 8:11]
# Out:
#                  City       State
# Year
# 2023         Glendale     Arizona
# 2022        Inglewood  California
# 2021            Tampa     Florida
# 2020    Miami Gardens     Florida
# 2019          Atlanta     Georgia
# 2018      Minneapolis   Minnesota
# 2017          Houston       Texas
# 2016      Santa Clara  California
# 2015         Glendale     Arizona
# 2014  East Rutherford  New Jersey

# %% [markdown]
# Now to focus on cities, we will see what cities have hosted this competition and sort them by the numbers of times hosted and then represent this on a bar plot

# %%
city_count1 = superbowl_new.groupby('City').sum()['Count'].reset_index().sort_values(by = 'Count', ascending=False)
city_count1.head()
# Out:
#              City  Count
# 13    New Orleans     10
# 11  Miami Gardens      6
# 10          Miami      5
# 19          Tampa      5
# 15       Pasadena      5

# %%
plt.figure(figsize=(12,4))
x = sns.barplot(x='City', y='Count', data=city_count1.head())
x.set_title('Top 5 host Cities', y=1.15)
x.set(xlabel='City', ylabel='Count')
plt.show()

# %% [markdown]
# Now to move on to top 5 states to have had a game played in their area.

# %%
state_count = superbowl_new.groupby('State').sum()['Count'].reset_index().sort_values(by = 'Count', ascending=False)
state_count.head()
# Out:
#         State  Count
# 2     Florida     17
# 1  California     13
# 5   Louisiana     10
# 0     Arizona      4
# 9       Texas      4

# %%
plt.figure(figsize=(40,10))
x = sns.barplot(x='State', y='Count', data=state_count.head())
x.set_title('Top 5 States to host this competition', y=1)
x.set(xlabel='State', ylabel='Count')
plt.show()

# %% [markdown]
# I will now scrape information from wikipedia on who has performed the national anthem each year at the superbowl

# %%
wiki_url = requests.get('https://en.wikipedia.org/wiki/List_of_national_anthem_performers_at_the_Super_Bowl')
tv = bs(wiki_url.content, 'lxml')

# %%
table = tv.find("table", {"class":"wikitable"})

# %%
pd.read_html(str(table))[0]
# Out:
#         No.  Yearly                                              Venue  \
# 0         I    1967          Los Angeles Memorial Coliseum, California
# 55      LVI    2022                SoFi Stadium, Inglewood, California
# 56     LVII    2023              State Farm Stadium, Glendale, Arizona
#
#                                       Performer(s)[1]
# 0   The Pride of Arizona, Michigan Marching Band, ...
# 1                             GSU Tiger Marching Band
# 2   Lloyd Geisler of the Washington National Symph...
# 3   Doc Severinsen,[3] Pat O'Brien (actor who play...
# 4                                 Tommy Loy (trumpet)
# 5                      U.S. Air Force Academy Chorale
# 6   Little Angels (children's choir) of Chicago's ...
# 7                                       Charley Pride
# 8   New Orleans Chapter of the Society for the Pre...
# 9                                        Tom Sullivan
# 10     None (Vikki Carr sang "America the Beautiful")
# 11  Phyllis Kelly of Northeast Louisiana Universit...
# 12                               The Colgate Thirteen
# 13                                        Cheryl Ladd
# 14                                    Helen O'Connell
# 15                                         Diana Ross
# 16                                 Leslie Easterbrook
# 17                                      Barry Manilow
# 18  San Francisco Boys Chorus, San Francisco Girls...
# 19                          Wynton Marsalis (trumpet)
# 20                                       Neil Diamond
# 21                              Herb Alpert (trumpet)
# 22                                         Billy Joel
# 23                                      Aaron Neville
# 24  Whitney Houston with Florida Orchestra directe...
# 25  Harry Connick Jr.ASL (American Sign Language):...
# 26                     Garth BrooksASL: Marlee Matlin
# 27               Natalie ColeASL: Courtney Keel Foley
# 28          Kathie Lee GiffordASL: Heather Whitestone
# 29                Vanessa WilliamsASL: Mary Kim Titla
# 30          Luther VandrossASL: Erika Rachael Schwarz
# 31                          JewelASL: Phyllis Frelich
# 32                            CherASL: Speaking Hands
# 33  Faith HillASL: Briarlake Elementary School Sig...
# 34                     Backstreet BoysASL: Tom Cooney
# 35                      Mariah CareyASL: Joe Narcisse
# 36                     Dixie ChicksASL: Janet Maxwell
# 37                        BeyoncéASL: Suzanna Christy
# 38  Combined choirs of the U.S. Military Academy, ...
# 39  Aaron Neville (2) and Aretha FranklinDr. John ...
# 40              Billy Joel (2) ASL: Marlee Matlin (2)
# 41                     Jordin SparksASL: A Dreamer[5]
# 42                 Jennifer HudsonASL: Kristen Santos
# 43               Carrie UnderwoodASL: Kinesha Battles
# 44         Christina AguileraASL: Candice Villesca[6]
# 45               Kelly ClarksonASL: Rachel Mazique[7]
# 46                Alicia Keys[8] ASL: John Maucere[9]
# 47                       Renée FlemingASL: Amber Zion
# 48              Idina MenzelASL: Treshelle Edmond[11]
# 49                Lady GagaASL: Marlee Matlin (3)[12]
# 50            Luke BryanASL: Kriston Lee Pumphrey[13]
# 51                     PinkASL: Alexandria Wailes[14]
# 52                   Gladys KnightASL: Aarron Loggins
# 53                  Demi LovatoASL: Christine Sun Kim
# 54  Eric Church and Jazmine SullivanASL: Warren Snipe
# 55                 Mickey GuytonASL: Sandra Mae Frank
# 56                    Chris StapletonASL: Troy Kotsur

# %% [markdown]
# Finally we will move on to the MVP award to see who has won this iconic achievement whilst competing in this event

# %%
plt.figure(figsize=(40,28))
mvp = sns.countplot(y='MVP', data=superbowl_new)
mvp.set_title('Most MVP awards won', y=1)
plt.show()
